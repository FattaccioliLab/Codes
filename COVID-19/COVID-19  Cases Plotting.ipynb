# %% [markdown]
# ## Confirmed Cases

# %%
import pandas as pd
import matplotlib as mp


url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv"
df=pd.read_csv(url, sep=',')
df=df.drop(columns=['Province/State', 'Lat', 'Long'])
df=df.groupby('Country/Region').sum()
df=df.transpose()
df['Days'] = df.reset_index().index
countries=['France', 'Italy', 'Spain', 'China', 'Germany', 'United Kingdom', 'Japan', 'US']
ax1 = df.plot(x='Days',y=countries, logy=True, figsize=(8,8), fontsize=14)

# %% [markdown]
# ## Deaths

# %%
url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Deaths.csv"
df=pd.read_csv(url, sep=',')
df=df.drop(columns=['Province/State', 'Lat', 'Long'])
df=df.groupby('Country/Region').sum()
df=df.transpose()
df['Days'] = df.reset_index().index
countries=['France', 'Italy', 'Spain', 'China', 'Germany', 'United Kingdom', 'Japan', 'US']
ax1 = df.plot(x='Days',y=countries, logy=True, figsize=(8,8), fontsize=14)
ax1.set_xlabel("Days since 2020/01/20", fontsize=14)
ax1.set_ylabel("Death counts", fontsize=14)
# Out:
# Text(0, 0.5, 'Death counts')
